# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read data file

# %%
data=pd.read_csv("/content/Dataset09-Employee-salary-prediction.csv")
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.shape
# Out:
# (375, 6)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
data.columns=['Age', 'Gender', 'Degree', 'Job Title', 'Experience_Years', 'Salary']

# %%
data.head()
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0

# %%
data.dtypes
# Out:
# Age                 float64
# Gender               object
# Degree               object
# Job Title            object
# Experience_Years    float64
# Salary              float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               373 non-null    float64
#  1   Gender            373 non-null    object
#  2   Degree            373 non-null    object
#  3   Job Title         373 non-null    object
#  4   Experience_Years  373 non-null    float64
#  5   Salary            373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
data[data.duplicated()]
# Out:
#       Age  Gender      Degree                              Job Title  \
# 195  28.0    Male  Bachelor's                Junior Business Analyst
# 250  30.0  Female  Bachelor's           Junior Marketing Coordinator
# 251  38.0    Male    Master's                   Senior IT Consultant
# 252  45.0  Female         PhD                Senior Product Designer
# 253  28.0    Male  Bachelor's  Junior Business Development Associate
# 254  35.0  Female  Bachelor's               Senior Marketing Analyst
# 255  44.0    Male  Bachelor's               Senior Software Engineer
# 256  34.0  Female    Master's               Senior Financial Advisor
# 257  35.0    Male  Bachelor's             Senior Project Coordinator
# 258  50.0  Female         PhD                 Director of Operations
# 260   NaN     NaN         NaN                                    NaN
# 262  46.0    Male         PhD                  Senior Data Scientist
# 281  41.0  Female  Bachelor's             Senior Project Coordinator
# ...

# %% [markdown]
# Drop Duplicate

# %%
data1=data.drop_duplicates(keep='first')
data1.shape
# Out:
# (325, 6)

# %% [markdown]
# Null value in the each column:

# %%
data1.isnull().sum()
# Out:
# Age                 1
# Gender              1
# Degree              1
# Job Title           1
# Experience_Years    1
# Salary              1
# dtype: int64

# %% [markdown]
# Dropping missing value from data:

# %%
data1.dropna(how='any', inplace=True)
# Out:
# /tmp/ipython-input-17-3932506268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.dropna(how='any', inplace=True)

# %%
data1.shape
# Out:
# (324, 6)

# %%
data1.head()
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0

# %% [markdown]
# Statistics of numerical value:

# %%
data1.describe()
# Out:
#               Age  Experience_Years         Salary
# count  324.000000        324.000000     324.000000
# mean    37.382716         10.058642   99985.648148
# std      7.185844          6.650470   48652.271440
# min     23.000000          0.000000     350.000000
# 25%     31.000000          4.000000   55000.000000
# 50%     36.500000          9.000000   95000.000000
# 75%     44.000000         16.000000  140000.000000
# max     53.000000         25.000000  250000.000000

# %% [markdown]
# correlation among the numerical features:

# %%
corr=data1[['Age', 'Experience_Years', 'Salary']].corr()
corr
# Out:
#                        Age  Experience_Years    Salary
# Age               1.000000          0.979192  0.916543
# Experience_Years  0.979192          1.000000  0.924455
# Salary            0.916543          0.924455  1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
data1['Degree'].value_counts()
# Out:
# Degree
# Bachelor's    191
# Master's       91
# PhD            42
# Name: count, dtype: int64

# %% [markdown]
# Data visualization

# %%
data1['Degree'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Degree'>

# %%
data1['Job Title'].value_counts()
# Out:
# Job Title
# Director of Operations            9
# Director of Marketing             8
# Senior Marketing Manager          8
# Senior Project Manager            7
# Senior Data Scientist             6
#                                  ..
# Junior Social Media Specialist    1
# Junior Operations Coordinator     1
# Senior HR Specialist              1
# Director of HR                    1
# Junior Financial Advisor          1
# Name: count, Length: 174, dtype: int64

# %%
data1['Age'].value_counts().plot(kind ='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
data1['Age'].value_counts().plot(kind ='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data1['Age'].value_counts().plot(kind ='box')
# Out:
# <Axes: >

# %% [markdown]
# Feature Engineering:

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder=LabelEncoder()

# %%
data1['Gender_Encode']=Label_Encoder.fit_transform(data1['Gender'])
# Out:
# /tmp/ipython-input-42-4041026452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Gender_Encode']=Label_Encoder.fit_transform(data1['Gender'])

# %%
data1['Degree_Encode']=Label_Encoder.fit_transform(data1['Degree'])
# Out:
# /tmp/ipython-input-43-2164431551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Degree_Encode']=Label_Encoder.fit_transform(data1['Degree'])

# %%
data1['Job Title_Encode']=Label_Encoder.fit_transform(data1['Job Title'])
# Out:
# /tmp/ipython-input-45-35525111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Job Title_Encode']=Label_Encoder.fit_transform(data1['Job Title'])

# %%
data1.head()
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary  \
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0
#
#    Gender_Encode  Degree_Encode  Job Title_Encode
# 0              1              0               159
# 1              0              1                17
# 2              1              2               130
# 3              0              0               101
# 4              1              1                22

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %% [markdown]
# Feature Scaling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

data=pd.read_csv("/content/Dataset09-Employee-salary-prediction.csv")
data.columns=['Age', 'Gender', 'Degree', 'Job Title', 'Experience_Years', 'Salary']
data1=data.drop_duplicates(keep='first').dropna(how='any').copy()
display(data1.head())

std_scaler = StandardScaler()
data1['Age_scaled'] = std_scaler.fit_transform(data1[['Age']])
display(data1.head())
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0
#     Age  Gender      Degree          Job Title  Experience_Years    Salary  \
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0
#
#    Age_scaled
# 0   -0.750231
# 1   -1.307742
# 2    1.061680
# ...

# %%
data1['Experience_Years_scaled']=std_scaler.fit_transform(data1[['Experience_Years']])
display(data1.head())
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary  \
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0
#
#    Age_scaled  Experience_Years_scaled
# 0   -0.750231                -0.761821
# 1   -1.307742                -1.063017
# 2    1.061680                 0.744158
# 3   -0.192720                -0.460625
# 4    2.037324                 1.497148

# %% [markdown]
# Dependent and independent features:

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder=LabelEncoder()
data1['Gender_Encode']=Label_Encoder.fit_transform(data1['Gender'])
data1['Degree_Encode']=Label_Encoder.fit_transform(data1['Degree'])
data1['Job Title_Encode']=Label_Encoder.fit_transform(data1['Job Title'])
display(data1.head())
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary  \
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0
#
#    Age_scaled  Experience_Years_scaled  Gender_Encode  Degree_Encode  \
# 0   -0.750231                -0.761821              1              0
# 1   -1.307742                -1.063017              0              1
# 2    1.061680                 0.744158              1              2
# 3   -0.192720                -0.460625              0              0
# 4    2.037324                 1.497148              1              1
#
#    Job Title_Encode
# 0               159
# 1                17
# 2               130
# ...

# %% [markdown]
# splitting the data into training and testing:

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((259, 5), (259,))

# %%
x_train.head()
# Out:
#      Age_scaled  Experience_Years_scaled  Gender_Encode  Degree_Encode  \
# 73    -1.307742                -1.213615              1              0
# 182    0.922302                 0.744158              0              2
# 17     0.225413                 0.292364              1              2
# 24     0.504169                 0.442962              1              1
# 146    0.643547                 0.894756              0              2
#
#      Job Title_Encode
# 73                166
# 182               155
# 17                116
# 24                 37
# 146               115

# %% [markdown]
# Model development:

# %%
from sklearn.linear_model import LinearRegression

# %%
Linear_regressor=LinearRegression()

# %% [markdown]
# Model training:

# %%
Linear_regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model prediction:

# %%
y_pred=Linear_regressor.predict(x_test)
y_pred
# Out:
# array([117415.91344602, 125562.80742758,  48965.15386167, 128739.34887988,
#        106828.49930535,  99654.76748821,  49101.27883652,  57130.71108104,
#        166333.69009266,  43112.61060113,  40544.18249367, 122553.217185  ,
#        107631.15450848, 155580.48335296,  83652.23602446, 170890.28450907,
#         98984.50106226, 109338.33008328,  42267.86835535,  48089.87647812,
#         75674.93528581,  64499.29874156,  63619.2494321 ,  31543.41552147,
#        188376.92844437,  90340.76921722, 155285.91529198, 160863.57809872,
#        185183.73163709,  34741.26224478, 124850.6230462 , 165106.94121635,
#         87085.00622186, 155425.69514031, 149190.25441885,  45729.74800187,
#         88475.39474629,  92025.62668073,  97997.32557607,  40411.112659  ,
#         89995.79796521,  53873.21977084, 108677.48549927,  54590.96778663,
#         36497.92729223,  48611.85493217, 129193.72126941,  43102.58902589,
# ...

# %%
df=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df['Errpr']=df['Actual']-df['Predicted']
df['abs_error']=abs(df['Errpr'])
df
# Out:
#        Actual      Predicted         Errpr     abs_error
# 132  100000.0  117415.913446 -17415.913446  17415.913446
# 108  100000.0  125562.807428 -25562.807428  25562.807428
# 137   50000.0   48965.153862   1034.846138   1034.846138
# 9    110000.0  128739.348880 -18739.348880  18739.348880
# 181  105000.0  106828.499305  -1828.499305   1828.499305
# ..        ...            ...           ...           ...
# 104   80000.0  117279.788471 -37279.788471  37279.788471
# 233   85000.0   83396.821876   1603.178124   1603.178124
# 60   170000.0  177743.761029  -7743.761029   7743.761029
# 94    75000.0   72275.144274   2724.855726   2724.855726
# 278   95000.0   86307.613619   8692.386381   8692.386381
#
# [65 rows x 4 columns]

# %%
df['Errpr']=df['Actual']-df['Predicted']
df['abs_error']=abs(df['Errpr'])
mean_abs_error=df['abs_error'].mean()
mean_abs_error
# Out:
# np.float64(10570.786401136185)

# %%
from sklearn.metrics import accuracy_score, r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8911231066517087

# %%
print(f'Accurecy of the model={r2_score(y_test,y_pred)}')
# Out:
# Accurecy of the model=0.8911231066517087

# %% [markdown]
# mean absolute error:

# %%
round(mean_absolute_error(y_test,y_pred),2)
# Out:
# 10570.79

# %% [markdown]
# mean squared error:

# %%
mse=round(mean_squared_error(y_test,y_pred),2)
mse
# Out:
# 205754135.72

# %% [markdown]
# Root mean square:

# %%
print('Root mean square error=',mse**(0.5))
# Out:
# Root mean square error= 14344.132449193294

# %% [markdown]
# coefficients:

# %%
Linear_regressor.coef_
# Out:
# array([2.01818940e+04, 1.92043082e+04, 7.38907834e+03, 1.54227359e+04,
#        1.95769562e+01])

# %% [markdown]
# intercepts:

# %%
Linear_regressor.intercept_
# Out:
# np.float64(86001.49320553207)

# %% [markdown]
# Custimize prediction:

# %%
data1.head()
# Out:
#     Age  Gender      Degree          Job Title  Experience_Years    Salary  \
# 0  32.0    Male  Bachelor's  Software Engineer               5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst               3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager              15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate               7.0   60000.0
# 4  52.0    Male    Master's           Director              20.0  200000.0
#
#    Age_scaled  Experience_Years_scaled  Gender_Encode  Degree_Encode  \
# 0   -0.750231                -0.761821              1              0
# 1   -1.307742                -1.063017              0              1
# 2    1.061680                 0.744158              1              2
# 3   -0.192720                -0.460625              0              0
# 4    2.037324                 1.497148              1              1
#
#    Job Title_Encode
# 0               159
# 1                17
# 2               130
# ...
